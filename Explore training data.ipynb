# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from IPython.html.widgets import interact
import pandas as pd
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('train_per_pixel.csv')

# %%
df.describe()
# Out:
#        amsr_swe_smoothed  recon_swe_mean       sca_mean     sca_stddev
# count       3.830700e+05   379680.000000  379680.000000  379680.000000
# mean        2.842489e+01       88.290331       0.190208       0.069095
# std         4.737547e+01      209.839335       0.291316       0.085989
# min        -3.552714e-15        0.000000       0.000000       0.000000
# 25%         0.000000e+00        0.000000       0.000000       0.000000
# 50%         1.363398e+00        0.508892       0.007860       0.031887
# 75%         3.974231e+01       21.161644       0.302207       0.118989
# max         2.500000e+02     1389.884888       0.967560       0.425373

# %%
df.hist(bins=20, figsize=(12,8))
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x109bdf950>,
#         <matplotlib.axes.AxesSubplot object at 0x109b84b50>],
#        [<matplotlib.axes.AxesSubplot object at 0x109de7a10>,
#         <matplotlib.axes.AxesSubplot object at 0x10b1588d0>]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(df, alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x10bcb1610>,
#         <matplotlib.axes.AxesSubplot object at 0x109b57cd0>,
#         <matplotlib.axes.AxesSubplot object at 0x10984fcd0>,
#         <matplotlib.axes.AxesSubplot object at 0x1097d8e10>],
#        [<matplotlib.axes.AxesSubplot object at 0x1099f3d10>,
#         <matplotlib.axes.AxesSubplot object at 0x109bd7c50>,
#         <matplotlib.axes.AxesSubplot object at 0x109965f90>,
#         <matplotlib.axes.AxesSubplot object at 0x10bfc9050>],
#        [<matplotlib.axes.AxesSubplot object at 0x10c0d0b10>,
#         <matplotlib.axes.AxesSubplot object at 0x10c1508d0>,
#         <matplotlib.axes.AxesSubplot object at 0x10c1b3bd0>,
#         <matplotlib.axes.AxesSubplot object at 0x10c23ea90>],
#        [<matplotlib.axes.AxesSubplot object at 0x10c2975d0>,
#         <matplotlib.axes.AxesSubplot object at 0x10c324890>,
#         <matplotlib.axes.AxesSubplot object at 0x10c46ea10>,
#         <matplotlib.axes.AxesSubplot object at 0x10e555290>]], dtype=object)

# %%
rows = np.random.choice(df.index.values, 10000)
scatter_matrix(df.ix[rows], alpha=0.05, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x109d57190>,
#         <matplotlib.axes.AxesSubplot object at 0x1155203d0>,
#         <matplotlib.axes.AxesSubplot object at 0x1101db490>,
#         <matplotlib.axes.AxesSubplot object at 0x10a8ab790>],
#        [<matplotlib.axes.AxesSubplot object at 0x10a973710>,
#         <matplotlib.axes.AxesSubplot object at 0x10c33ae50>,
#         <matplotlib.axes.AxesSubplot object at 0x10c527c10>,
#         <matplotlib.axes.AxesSubplot object at 0x10c58c910>],
#        [<matplotlib.axes.AxesSubplot object at 0x10c60c7d0>,
#         <matplotlib.axes.AxesSubplot object at 0x10c644850>,
#         <matplotlib.axes.AxesSubplot object at 0x10cb70350>,
#         <matplotlib.axes.AxesSubplot object at 0x10cbf2110>],
#        [<matplotlib.axes.AxesSubplot object at 0x10cc56410>,
#         <matplotlib.axes.AxesSubplot object at 0x10ccdf2d0>,
#         <matplotlib.axes.AxesSubplot object at 0x10cd2cdd0>,
#         <matplotlib.axes.AxesSubplot object at 0x10e6170d0>]], dtype=object)

# %%
df.corr()
# Out:
#                    amsr_swe_smoothed  recon_swe_mean  sca_mean  sca_stddev
# amsr_swe_smoothed           1.000000        0.726983  0.853832    0.518827
# recon_swe_mean              0.726983        1.000000  0.828271    0.246929
# sca_mean                    0.853832        0.828271  1.000000    0.562791
# sca_stddev                  0.518827        0.246929  0.562791    1.000000

# %%
df.corr()**2
# Out:
#                    amsr_swe_smoothed  recon_swe_mean  sca_mean  sca_stddev
# amsr_swe_smoothed           1.000000        0.528504  0.729030    0.269182
# recon_swe_mean              0.528504        1.000000  0.686033    0.060974
# sca_mean                    0.729030        0.686033  1.000000    0.316733
# sca_stddev                  0.269182        0.060974  0.316733    1.000000
