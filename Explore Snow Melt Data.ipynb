# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from IPython.html.widgets import interact
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from explore import Explorer

# %%
explorer = Explorer('smooth_afghan_AMSRE_h23v05_WY2009.h5', 'Grid/MODIS_GRID_10km/amsr_swe_smoothed')
# Out:
# Read dataset with dimensions: (365, 113, 113)

# %%
interact(lambda day: explorer.plot_day(day), day=[0,364])

# %% [markdown]
# - Snow data indexing: 0 is October 1st
# - Reconstruction indexing: 0 is Jan 1st
# - April is the most important month, so we want to only extract training & testing data from April

# %%
sca_explorer = Explorer('h23v05_WY2009_10km.h5', 'Grid/MODIS_GRID_10km/sca_mean')
# Out:
# Read dataset with dimensions: (365, 113, 113)

# %%
interact(lambda day: sca_explorer.plot_day(day), day=[0,364])

# %%
recon_swe_explorer = Explorer('ReconSWE_h23v05_2009_10km.h5', 'Grid/MODIS_GRID_10km/swe_mean')
# Out:
# Read dataset with dimensions: (273, 113, 113)

# %%
interact(lambda day: recon_swe_explorer.plot_day(day), day=[0,272])
